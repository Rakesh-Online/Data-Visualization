# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
print(sns.__version__)
# Out:
# 0.11.0

# %%
#To update seaborn
#!pip install seaborn --upgrade

# %% [markdown]
# # inbuilt datasets of seaborn

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
heart = pd.read_csv(r'C:\Users\rakes\Documents\Raq files\Data Science\Data sets\clevelanda.csv')

# %%
heart.head()
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %% [markdown]
# # Attribute Information

# %%
#age: age in years
#sex: sex (1 = male; 0 = female) 

#cp: chest pain type
# -- Value 1: typical angina
# -- Value 2: atypical angina
# -- Value 3: non-anginal pain
# -- Value 4: asymptomatic

#trestbps: resting blood pressure (in mm Hg on admission to the hospital)
#chol: serum cholestoral in mg/dl
#fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#restecg: resting electrocardiographic results
# -- Value 0: normal
# -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# -- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#thalach: maximum heart rate achieved
#exang: exercise induced angina (1 = yes; 0 = no)
#oldpeak = ST depression induced by exercise relative to rest
#slope: the slope of the peak exercise ST segment
# -- Value 1: upsloping
# -- Value 2: flat
# -- Value 3: downsloping
#ca: number of major vessels (0-3) colored by flourosopy
#thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#  num: diagnosis of heart disease (angiographic disease status)
# -- Value 0: < 50% diameter narrowing
# -- Value 1: > 50% diameter narrowing
# (in any major vessel: attributes 59 through 68 are vessels)

# %% [markdown]
# # Seaborn

# %%
sns.lineplot(x=heart['age'], y= heart['thalach'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='thalach'>

# %%
sns.barplot(x=heart['class'], y= heart['age'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
heart['age'].describe()
# Out:
# count    303.000000
# mean      54.438944
# std        9.038662
# min       29.000000
# 25%       48.000000
# 50%       56.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
sns.boxplot(heart['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.distplot(heart['age'])
# Out:
# C:\Users\rakes\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.countplot(heart['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.relplot(x= 'age', y= 'class', data= heart)

# %%
sns.catplot(x="class", y="thalach", hue='gender' ,data=heart)

# %%
sns.catplot(x="class", y="thalach", hue='gender' ,data=heart, kind='violin')

# %%
sns.catplot(x="class", y="thalach" ,data=heart, kind='boxen')

# %%
sns.scatterplot(x=heart['age'], y= heart['thalach'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='thalach'>

# %%
sns.jointplot(x=heart['age'], y=heart['thalach'], kind="kde", color="b")

# %%
b = sns.FacetGrid(heart, col="class") 
b.map(plt.hist, "age")

# %%
b = sns.PairGrid(heart[['age', 'thalach']]) 
b.map(plt.scatter)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(heart.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pointplot(x='class', y='age', data=heart)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
heart.columns
# Out:
# Index(['age', 'gender', 'cp', 'trestbps', 'chol', 'fps', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'class'],
#       dtype='object')

# %%
g = sns.FacetGrid(heart, col="class" , height=3, col_wrap=2)
g.map_dataframe(sns.scatterplot, x="age", y="thalach")

# %%
sns.histplot(data=heart, x="age", hue="class", multiple="stack")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.countplot(heart['age'])
# Out:
# C:\Users\rakes\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.displot(heart, x="age", kind="kde")
